# %% [markdown]
# <a href="https://colab.research.google.com/github/jesivan-t/cpe310_damayo/blob/main/HandsOnActivity_Damayo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jes Ivan T. Damayo | BSIE | CPE310 - Fundamentals of Data Science | 1/27/2025 | Instructor: Engr. Roman M. Richard | Activity No. 2: Literals, Operators, and Variables

# %% [markdown]
# # Task 1 - Write the Python equivalent code of the following C code:

# %%
int main(){
float base = 0, height = 0, area = 0;
printf(“Enter the base of the triangle: “);
scanf(“%f”, &base);
printf(“Enter the height of the triangle: “);
scanf(“%f”, &height);
area = (1/2)*base*height;
print(“The area of the triangle is %f”, area);
}

# %%
base = float(input("Enter the base of the triangle: "))
height = float(input("Enter the height of the triangle: "))
area = float((1/2)*base*height)
print("The area of the triangle is: ", area)
# Out:
# Enter the base of the triangle: 43
# Enter the height of the triangle: 4
# The area of the triangle is:  86.0

# %% [markdown]
# # Task 2 - Write a program that would convert Celsius to Fahrenheit given the formula: F = (C × 9/5) + 32

# %%
clc = float(input("Enter temperature in Celsius: "))
fhr = float(clc*(9/5)+32)
print(clc, " degrees C is ", fhr ,"degrees F")
# Out:
# Enter temperature in Celsius: 34
# 34.0  degrees C is  93.2 degrees F

# %% [markdown]
# # Task 3 - Write a program that can determine the distance between two points given the coordinates using the formula: 𝒅 = √(𝒙𝟐 − 𝒙𝟏)𝟐 + (𝒚𝟐 − 𝒚𝟏)𝟐

# %%
import math
x1 = float(input("Enter x1: "))
x2 = float(input("Enter x2: "))
y1 = float(input("Enter y1: "))
y2 = float(input("Enter y2: "))
d = math.sqrt((x2-x1)**2+(y2-y1)**2)
print(d)
# Out:
# Enter x1: 2
# Enter x2: -3
# Enter y1: 2
# Enter y2: 3
# 5.0990195135927845

# %% [markdown]
# # Give one major difference in syntax that Python has with other languages such as C.

# %% [markdown]
# One major difference between Python and C is the way they handle code blocks. Python uses indentation while C uses curly braces {} to define code blocks.

# %% [markdown]
# # How does variable assignment differ in Python compared with other languages such as C?

# %% [markdown]
# In Python, it's not required to declare the type of a variable. There is no declaration needed, and you can freely reassign the type of a variable with a new value of a different type. In C, you must declare the type of a variable before using it. Once a variable is declared with a type, it can only hold values of that type.

# %% [markdown]
# # Try assigning variable names that start with numbers, and special characters. Is the assigning of variables that start with numbers accepted by Python? For Special Characters? Is there an exception for variables special characters?

# %% [markdown]
# There are rules for naming variables in Python, and one of those rules is that variables cannot start with numbers. Just like other programming languages, special characters are not allowed in variable namings. The underscore _ is the only character allowed in naming variables.

# %% [markdown]
# # Do the assignment operators (+, -, *, /, %, **) work for all data types? Why or Why not?

# %% [markdown]
# Assignment operators work wth data types where the operation makes logical sense. **They do not work for all data types.** A mismatch between an operator and a data type will prompt Python to raise an error.

# %% [markdown]
# # How does the * operator differ from the ** operator?

# %% [markdown]
# The * operator is used for multiplication. The ** operator is used for exponentiation, which means you raise a number to the power of another number.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# This activity was very fun and engaging as I have started working with a new kind of programming language called Python. When I first encountered Python, I was amazed by its versatility, simplicity, and compact nature. It is less challenging to code with Python than with C or C++. Variable declaration was not required, which streamlined my coding. I am excited to learn more about Python and explore its full potential on upcoming activities or projects.

# %% [markdown]
# # Proof of work

# %% [markdown]
# ![Screenshot 2025-01-27 214725.png](data:image/png;base64,...)
